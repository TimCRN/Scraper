# %%
## Importeren van libraries
import pandas as pd
import os
import datetime
pd.__version__
# Out:
# '1.4.2'

# %%
## Dataset variabele
dataset = "\\huurwoningentotaal.xlsx"
## Ophalen van de datasets
pwd = os.getcwd()
dataset = pd.read_excel(pwd + dataset)

# %%
dataset
# Out:
#                           Plek                    Wijk Postcode  \
# 0                 Nassaustraat             Nassaubuurt  5046 NS
# 1     Godijn van Dormaalstraat           Het Lage Land  3067 JJ
# 2                   Korte Mare               Noordvest  2312 NN
# 3                   Langstraat                 Centrum  5801 AA
# 4                    Pascalerf                 Besterd  5014 EW
# ...                        ...                     ...      ...
# 1955                Kerkstraat            Victor Noord  2211 RJ
# 1956       Jan ten Brinkstraat  Haag Laakkwartier-Oost  2522 HV
# 1957               Dorpsstraat               Vreeswijk  3433 CJ
# 1958               Sprengenweg       Sprengenweg-Noord  7314 ES
# 1959                Werfstraat        Noorderplantsoen  9712 VN
#
#            Plaatsnaam   Prijs  Oppervlakte  Kamers     Interieur  \
# 0             Tilburg    1.18           59     3.0   Gestoffeerd
# ...

# %%
## Huidige datum krijgen (Jaar-Maand-Dag)
now = datetime.datetime.now()
current_time = now.strftime("%Y-%m-%d")
current_time

# %%
dataset["Updated"] = current_time

# %%
dataset["Status"] = 'TBD'

# %%
pwd = os.getcwd()
dataset.to_excel(pwd + "\\huurwoningentotaal1.xlsx", index=False)
